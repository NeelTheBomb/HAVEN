# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), "..", "..", "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", ".."))
sys.path
# Out:
# ['/home/blessyantony/miniconda3/envs/haven/lib/python311.zip',
#  '/home/blessyantony/miniconda3/envs/haven/lib/python3.11',
#  '/home/blessyantony/miniconda3/envs/haven/lib/python3.11/lib-dynload',
#  '',
#  '/home/blessyantony/miniconda3/envs/haven/lib/python3.11/site-packages',
#  '/home/blessyantony/dev/git/HAVEN/src/jupyter_notebooks/few_shot_learning/../../../../..',
#  '/home/blessyantony/dev/git/HAVEN/src/jupyter_notebooks/few_shot_learning/../../../..',
#  '/home/blessyantony/dev/git/HAVEN/src/jupyter_notebooks/few_shot_learning/../../..',
#  '/home/blessyantony/dev/git/HAVEN/src/jupyter_notebooks/few_shot_learning/../..']

# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pathlib import Path
import textwrap
from sklearn.metrics import roc_curve, accuracy_score, f1_score, auc, precision_recall_curve
from statistics import mean

from src.utils import utils, evaluation_utils, visualization_utils

# %%
#tf_output_file_path = os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240613/host_multi/few_shot_learning/fsl_non_idv_uniref90viridae_msl2048_transformer-l_6-h_8-d_1024-lr1e-4_classwise_auprc.csv")
# virprobert_80_20_output_file_path = os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240625/host_multi/few_shot_learning/fsl_tr_w3s5q10_te_w3s5q-1_e25b32_msl2048_split70-10-20_virprobert_classwise_auprc.csv")
# virprobert_70_30_output_file_path = os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240625/host_multi/few_shot_learning/fsl_tr_w3s5q10_te_w3s5q-1_e25b32_msl2048_split60-10-30_virprobert_classwise_auprc.csv")
# virprobert_50_50_output_file_path = os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240625/host_multi/few_shot_learning/fsl_tr_w3s5q10_te_w3s5q-1_e25b32_msl2048_split40-10-50_virprobert_classwise_auprc.csv")
# virprobert_40_60_output_file_path = os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240625/host_multi/few_shot_learning/fsl_tr_w3s5q10_te_w3s5q-1_e25b32_msl2048_split30-10-60_virprobert_classwise_auprc.csv")

                                                 

virprobert_output_auprc_file_paths =  {
    "sl256st64_w3s5": os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240928/host_multi/few_shot_learning/fsl_tr_w3s5q10_te_w3s5q-1_e100b32_split70-10-20_hybrid-attention_sl256st64vs30cls_fnn_2l_d1024_lr1e-4_classwise_auprc.csv"),
    #"sl256st64_w5s2": os.path.join(os.getcwd(), "..","..", "..", "output/raw/uniref90_embl_vertebrates_non_idv/20240906/host_multi/few_shot_learning/fsl_tr_w5s2q10_te_w5s2q-1_e100b32_split70-10-20_hybrid-attention_sl256st64vs30_ae_bn_fnn_2l_d1024_lr1e-4_classwise_auprc.csv")
}
dataset_file_path = os.path.join(os.getcwd(), "..","..", "..", "input/data/uniref90/20240131/uniref90_viridae_embl_hosts_pruned_metadata_species_vertebrates_w_seq_non_idv_lt_1_gte_0.05_prcnt_prevalence_seq_len_in_99prcntile.csv")

# %%
def read_output_df(output_file_paths):
    dfs = []
    for model, output_file_path in output_file_paths.items():
        df = pd.read_csv(output_file_path, index_col=0)
        df["model"] = model
        dfs.append(df)
    return pd.concat(dfs)


def compute_class_distribution(df, label_col, n, format=False):
    labels_counts = df[label_col].value_counts()
    labels_counts = labels_counts / n * 100
    labels_counts = labels_counts.to_dict()
    if format:
        labels_counts = {k: f"{k}\n({v:.2f}%)" for k, v, in labels_counts.items()}
    return labels_counts

# %%
df = read_output_df(virprobert_output_auprc_file_paths)
dataset_df = pd.read_csv(dataset_file_path)

# %%
dataset_df.shape
# Out:
# (11116, 12)

# %%
metadata_formatted = compute_class_distribution(dataset_df, "virus_host_name", n=47792, format=True)
metadata_formatted
# Out:
# {'Cyprinus carpio': 'Cyprinus carpio\n(0.86%)',
#  'Petroica australis': 'Petroica australis\n(0.85%)',
#  'Felis catus': 'Felis catus\n(0.62%)',
#  'Gopherus morafkai': 'Gopherus morafkai\n(0.61%)',
#  'Peromyscus boylii': 'Peromyscus boylii\n(0.59%)',
#  'Marmota flaviventris': 'Marmota flaviventris\n(0.57%)',
#  'Bos taurus': 'Bos taurus\n(0.54%)',
#  'Eptesicus fuscus': 'Eptesicus fuscus\n(0.53%)',
#  'Macaca mulatta': 'Macaca mulatta\n(0.49%)',
#  'Loxodonta africana': 'Loxodonta africana\n(0.45%)',
#  'Mastomys natalensis': 'Mastomys natalensis\n(0.43%)',
#  'Gymnorhina tibicen': 'Gymnorhina tibicen\n(0.41%)',
#  'Eidolon helvum': 'Eidolon helvum\n(0.38%)',
#  'Sparus aurata': 'Sparus aurata\n(0.37%)',
#  'Ailurus fulgens': 'Ailurus fulgens\n(0.36%)',
#  'Elephas maximus': 'Elephas maximus\n(0.36%)',
#  'Oryzomys sp.': 'Oryzomys sp.\n(0.33%)',
#  'Lates calcarifer': 'Lates calcarifer\n(0.33%)',
#  'Bufo bufo': 'Bufo bufo\n(0.32%)',
#  'Crocodylus porosus': 'Crocodylus porosus\n(0.32%)',
#  'Hypsugo savii': 'Hypsugo savii\n(0.31%)',
#  'Equus caballus': 'Equus caballus\n(0.31%)',
#  'Dipodomys merriami': 'Dipodomys merriami\n(0.30%)',
#  'Rattus norvegicus': 'Rattus norvegicus\n(0.30%)',
#  'Crocodilurus amazonicus': 'Crocodilurus amazonicus\n(0.29%)',
#  'Tarsiger cyanurus': 'Tarsiger cyanurus\n(0.28%)',
#  'Chelonia mydas': 'Chelonia mydas\n(0.28%)',
#  'Mus musculus': 'Mus musculus\n(0.25%)',
#  'Tursiops aduncus': 'Tursiops aduncus\n(0.24%)',
#  'Ovis aries': 'Ovis aries\n(0.24%)',
#  'Tadarida brasiliensis': 'Tadarida brasiliensis\n(0.24%)',
#  'Rhinolophus ferrumequinum': 'Rhinolophus ferrumequinum\n(0.24%)',
#  'Heloderma suspectum': 'Heloderma suspectum\n(0.24%)',
#  'Pteropus scapulatus': 'Pteropus scapulatus\n(0.24%)',
#  'Anas superciliosa': 'Anas superciliosa\n(0.23%)',
#  'Squalius cephalus': 'Squalius cephalus\n(0.23%)',
#  'Oryctolagus cuniculus': 'Oryctolagus cuniculus\n(0.22%)',
#  'Coendou prehensilis': 'Coendou prehensilis\n(0.20%)',
#  'Anas castanea': 'Anas castanea\n(0.19%)',
#  'Grus japonensis': 'Grus japonensis\n(0.17%)',
#  'Amazona oratrix': 'Amazona oratrix\n(0.16%)',
#  'Callorhinus ursinus': 'Callorhinus ursinus\n(0.16%)',
#  'Phylloscopus inornatus': 'Phylloscopus inornatus\n(0.15%)',
#  'Macaca fuscata': 'Macaca fuscata\n(0.15%)',
#  'Hoplobatrachus rugulosus': 'Hoplobatrachus rugulosus\n(0.14%)',
#  'Phrynocephalus erythrurus': 'Phrynocephalus erythrurus\n(0.14%)',
#  'Miniopterus schreibersii': 'Miniopterus schreibersii\n(0.13%)',
#  'Peromyscus truei': 'Peromyscus truei\n(0.13%)',
#  'Marmota marmota': 'Marmota marmota\n(0.13%)',
#  'Rhinella marina': 'Rhinella marina\n(0.13%)',
#  'Gorilla gorilla': 'Gorilla gorilla\n(0.12%)',
#  'Camelus dromedarius': 'Camelus dromedarius\n(0.12%)',
#  'Rhinolophus sinicus': 'Rhinolophus sinicus\n(0.12%)',
#  'Pygoscelis antarcticus': 'Pygoscelis antarcticus\n(0.12%)',
#  'Equus asinus': 'Equus asinus\n(0.11%)',
#  'Pygoscelis adeliae': 'Pygoscelis adeliae\n(0.11%)',
#  'Boa constrictor': 'Boa constrictor\n(0.10%)',
#  'Ailuropoda melanoleuca': 'Ailuropoda melanoleuca\n(0.10%)',
#  'Myotis ricketti': 'Myotis ricketti\n(0.10%)',
#  'Rhinolophus affinis': 'Rhinolophus affinis\n(0.10%)',
#  'Rousettus aegyptiacus': 'Rousettus aegyptiacus\n(0.10%)',
#  'Leptonychotes weddellii': 'Leptonychotes weddellii\n(0.10%)',
#  'Ficedula parva': 'Ficedula parva\n(0.10%)',
#  'Macaca fascicularis': 'Macaca fascicularis\n(0.10%)',
#  'Myodes glareolus': 'Myodes glareolus\n(0.10%)',
#  'Motacilla cinerea': 'Motacilla cinerea\n(0.10%)',
#  'Myotis daubentonii': 'Myotis daubentonii\n(0.10%)',
#  'Retropinna retropinna': 'Retropinna retropinna\n(0.10%)',
#  'Apodemus flavicollis': 'Apodemus flavicollis\n(0.10%)',
#  'Acinonyx jubatus': 'Acinonyx jubatus\n(0.10%)',
#  'Turdus hortulorum': 'Turdus hortulorum\n(0.10%)',
#  'Desmodus rotundus': 'Desmodus rotundus\n(0.09%)',
#  'Larvivora sibilans': 'Larvivora sibilans\n(0.09%)',
#  'Phoenicurus auroreus': 'Phoenicurus auroreus\n(0.09%)',
#  'Cecropis daurica': 'Cecropis daurica\n(0.09%)',
#  'Phascolarctos cinereus': 'Phascolarctos cinereus\n(0.09%)',
#  'Aegithalos caudatus': 'Aegithalos caudatus\n(0.09%)',
#  'Miniopterus magnater': 'Miniopterus magnater\n(0.09%)',
#  'Vulpes vulpes': 'Vulpes vulpes\n(0.09%)',
#  'Scotophilus kuhlii': 'Scotophilus kuhlii\n(0.09%)',
#  'Pan troglodytes': 'Pan troglodytes\n(0.09%)',
#  'Anas platyrhynchos': 'Anas platyrhynchos\n(0.08%)',
#  'Emberiza spodocephala': 'Emberiza spodocephala\n(0.08%)',
#  'Ambystoma tigrinum': 'Ambystoma tigrinum\n(0.08%)',
#  'Phylloscopus fuscatus': 'Phylloscopus fuscatus\n(0.08%)',
#  'Enhydra lutris': 'Enhydra lutris\n(0.08%)',
#  'Rousettus leschenaultii': 'Rousettus leschenaultii\n(0.08%)',
#  'Grallina cyanoleuca': 'Grallina cyanoleuca\n(0.08%)',
#  'Cavia porcellus': 'Cavia porcellus\n(0.08%)',
#  'Sarcophilus harrisii': 'Sarcophilus harrisii\n(0.08%)',
#  'Chenonetta jubata': 'Chenonetta jubata\n(0.08%)',
#  'Papio anubis': 'Papio anubis\n(0.08%)',
#  'Pavo cristatus': 'Pavo cristatus\n(0.08%)',
#  'Pteropus tonganus': 'Pteropus tonganus\n(0.08%)',
#  'Apodemus agrarius': 'Apodemus agrarius\n(0.08%)',
#  'Capra hircus': 'Capra hircus\n(0.08%)',
#  'Dendrocopos leucotos': 'Dendrocopos leucotos\n(0.08%)',
#  'Pipistrellus pipistrellus': 'Pipistrellus pipistrellus\n(0.08%)',
#  'Lanius cristatus': 'Lanius cristatus\n(0.07%)',
#  'Fringilla montifringilla': 'Fringilla montifringilla\n(0.07%)',
#  'Anguilla australis': 'Anguilla australis\n(0.07%)',
#  'Meleagris gallopavo': 'Meleagris gallopavo\n(0.07%)',
#  'Luscinia cyanura': 'Luscinia cyanura\n(0.07%)',
#  'Rhinolophus thomasi': 'Rhinolophus thomasi\n(0.07%)',
#  'Pteropus giganteus': 'Pteropus giganteus\n(0.07%)',
#  'Arctocephalus tropicalis': 'Arctocephalus tropicalis\n(0.07%)',
#  'Mandrillus sphinx': 'Mandrillus sphinx\n(0.07%)',
#  'Rattus exulans': 'Rattus exulans\n(0.07%)',
#  'Periparus ater': 'Periparus ater\n(0.07%)',
#  'Kryptopterus bicirrhis': 'Kryptopterus bicirrhis\n(0.07%)',
#  'Vespertilio sinensis': 'Vespertilio sinensis\n(0.07%)',
#  'Cygnus columbianus': 'Cygnus columbianus\n(0.07%)',
#  'Arctocephalus australis': 'Arctocephalus australis\n(0.07%)',
#  'Alces alces': 'Alces alces\n(0.06%)',
#  'Phylloscopus proregulus': 'Phylloscopus proregulus\n(0.06%)',
#  'Corynorhinus rafinesquii': 'Corynorhinus rafinesquii\n(0.06%)',
#  'Python bivittatus': 'Python bivittatus\n(0.06%)',
#  'Prunella montanella': 'Prunella montanella\n(0.06%)',
#  'Microtus agrestis': 'Microtus agrestis\n(0.06%)',
#  'Macaca arctoides': 'Macaca arctoides\n(0.06%)',
#  'Felis domesticus': 'Felis domesticus\n(0.06%)',
#  'Rattus tanezumi': 'Rattus tanezumi\n(0.06%)',
#  'Pantholops hodgsonii': 'Pantholops hodgsonii\n(0.06%)',
#  'Miniopterus pusillus': 'Miniopterus pusillus\n(0.06%)',
#  'Zoothera dauma': 'Zoothera dauma\n(0.06%)',
#  'Turdus pallidus': 'Turdus pallidus\n(0.06%)',
#  'Spheniscus demersus': 'Spheniscus demersus\n(0.06%)',
#  'Erinaceus europaeus': 'Erinaceus europaeus\n(0.05%)',
#  'Emberiza chrysophrys': 'Emberiza chrysophrys\n(0.05%)',
#  'Turdus naumanni': 'Turdus naumanni\n(0.05%)',
#  'Odocoileus virginianus': 'Odocoileus virginianus\n(0.05%)',
#  'Phrynocephalus theobaldi': 'Phrynocephalus theobaldi\n(0.05%)',
#  'Acanthorhynchus tenuirostris': 'Acanthorhynchus tenuirostris\n(0.05%)',
#  'Suncus murinus': 'Suncus murinus\n(0.05%)',
#  'Gallus gallus domesticus': 'Gallus gallus domesticus\n(0.05%)',
#  'Eptesicus serotinus': 'Eptesicus serotinus\n(0.05%)',
#  'Anas gracilis': 'Anas gracilis\n(0.05%)',
#  'Tursiops truncatus': 'Tursiops truncatus\n(0.05%)',
#  'Salmo salar': 'Salmo salar\n(0.05%)',
#  'Cairina moschata': 'Cairina moschata\n(0.05%)',
#  'Phylloscopus schwarzi': 'Phylloscopus schwarzi\n(0.05%)',
#  'Rattus rattus': 'Rattus rattus\n(0.05%)',
#  'Python regius': 'Python regius\n(0.05%)'}

# %%
metadata_unformatted = compute_class_distribution(dataset_df, "virus_host_name", n=47792, format=False)
metadata_unformatted
# Out:
# {'Cyprinus carpio': 0.8578841647137595,
#  'Petroica australis': 0.8536993639102779,
#  'Felis catus': 0.6214429193170405,
#  'Gopherus morafkai': 0.610980917308336,
#  'Peromyscus boylii': 0.5900569132909274,
#  'Marmota flaviventris': 0.5670405088717777,
#  'Bos taurus': 0.5356545028456646,
#  'Eptesicus fuscus': 0.5314697020421828,
#  'Macaca mulatta': 0.48543689320388345,
#  'Loxodonta africana': 0.4456812855708068,
#  'Mastomys natalensis': 0.4331268831603616,
#  'Gymnorhina tibicen': 0.4059256779377301,
#  'Eidolon helvum': 0.3766320723133579,
#  'Sparus aurata': 0.36826247070639434,
#  'Ailurus fulgens': 0.3640776699029126,
#  'Elephas maximus': 0.35989286909943086,
#  'Oryzomys sp.': 0.33478406427854035,
#  'Lates calcarifer': 0.33059926347505864,
#  'Bufo bufo': 0.3180448610646133,
#  'Crocodylus porosus': 0.31595246066287247,
#  'Hypsugo savii': 0.305490458654168,
#  'Equus caballus': 0.305490458654168,
#  'Dipodomys merriami': 0.30339805825242716,
#  'Rattus norvegicus': 0.2950284566454637,
#  'Crocodilurus amazonicus': 0.28875125544024105,
#  'Tarsiger cyanurus': 0.2845664546367593,
#  'Chelonia mydas': 0.27828925343153665,
#  'Mus musculus': 0.2510880482089053,
#  'Tursiops aduncus': 0.24062604620020087,
#  'Ovis aries': 0.23853364579845998,
#  'Tadarida brasiliensis': 0.23853364579845998,
#  'Rhinolophus ferrumequinum': 0.23853364579845998,
#  'Heloderma suspectum': 0.23644124539671912,
#  'Pteropus scapulatus': 0.23644124539671912,
#  'Anas superciliosa': 0.2343488449949782,
#  'Squalius cephalus': 0.22597924338801473,
#  'Oryctolagus cuniculus': 0.21551724137931033,
#  'Coendou prehensilis': 0.19668563776364245,
#  'Anas castanea': 0.19040843655841982,
#  'Grus japonensis': 0.1736692333444928,
#  'Amazona oratrix': 0.1632072313357884,
#  'Callorhinus ursinus': 0.16111483093404752,
#  'Phylloscopus inornatus': 0.15065282892534315,
#  'Macaca fuscata': 0.14856042852360227,
#  'Hoplobatrachus rugulosus': 0.14437562772012053,
#  'Phrynocephalus erythrurus': 0.14437562772012053,
#  'Miniopterus schreibersii': 0.13182122530967524,
#  'Peromyscus truei': 0.13182122530967524,
#  'Marmota marmota': 0.12554402410445265,
#  'Rhinella marina': 0.12554402410445265,
#  'Gorilla gorilla': 0.11508202209574825,
#  'Camelus dromedarius': 0.11508202209574825,
#  'Rhinolophus sinicus': 0.11508202209574825,
#  'Pygoscelis antarcticus': 0.11508202209574825,
#  'Equus asinus': 0.11089722129226649,
#  'Pygoscelis adeliae': 0.10671242048878474,
#  'Boa constrictor': 0.10462002008704385,
#  'Ailuropoda melanoleuca': 0.10462002008704385,
#  'Myotis ricketti': 0.10462002008704385,
#  'Rhinolophus affinis': 0.10252761968530298,
#  'Rousettus aegyptiacus': 0.10252761968530298,
#  'Leptonychotes weddellii': 0.1004352192835621,
#  'Ficedula parva': 0.1004352192835621,
#  'Macaca fascicularis': 0.1004352192835621,
#  'Myodes glareolus': 0.09834281888182123,
#  'Motacilla cinerea': 0.09834281888182123,
#  'Myotis daubentonii': 0.09834281888182123,
#  'Retropinna retropinna': 0.09625041848008034,
#  'Apodemus flavicollis': 0.09625041848008034,
#  'Acinonyx jubatus': 0.09625041848008034,
#  'Turdus hortulorum': 0.09625041848008034,
#  'Desmodus rotundus': 0.09415801807833947,
#  'Larvivora sibilans': 0.09415801807833947,
#  'Phoenicurus auroreus': 0.09206561767659859,
#  'Cecropis daurica': 0.09206561767659859,
#  'Phascolarctos cinereus': 0.09206561767659859,
#  'Aegithalos caudatus': 0.08997321727485771,
#  'Miniopterus magnater': 0.08997321727485771,
#  'Vulpes vulpes': 0.08788081687311684,
#  'Scotophilus kuhlii': 0.08578841647137596,
#  'Pan troglodytes': 0.08578841647137596,
#  'Anas platyrhynchos': 0.08369601606963509,
#  'Emberiza spodocephala': 0.08369601606963509,
#  'Ambystoma tigrinum': 0.08369601606963509,
#  'Phylloscopus fuscatus': 0.0816036156678942,
#  'Enhydra lutris': 0.07951121526615333,
#  'Rousettus leschenaultii': 0.07951121526615333,
#  'Grallina cyanoleuca': 0.07951121526615333,
#  'Cavia porcellus': 0.07951121526615333,
#  'Sarcophilus harrisii': 0.07951121526615333,
#  'Chenonetta jubata': 0.07741881486441246,
#  'Papio anubis': 0.07741881486441246,
#  'Pavo cristatus': 0.07741881486441246,
#  'Pteropus tonganus': 0.07741881486441246,
#  'Apodemus agrarius': 0.07741881486441246,
#  'Capra hircus': 0.07532641446267158,
#  'Dendrocopos leucotos': 0.07532641446267158,
#  'Pipistrellus pipistrellus': 0.07532641446267158,
#  'Lanius cristatus': 0.0732340140609307,
#  'Fringilla montifringilla': 0.0732340140609307,
#  'Anguilla australis': 0.07114161365918982,
#  'Meleagris gallopavo': 0.07114161365918982,
#  'Luscinia cyanura': 0.07114161365918982,
#  'Rhinolophus thomasi': 0.07114161365918982,
#  'Pteropus giganteus': 0.07114161365918982,
#  'Arctocephalus tropicalis': 0.07114161365918982,
#  'Mandrillus sphinx': 0.06904921325744895,
#  'Rattus exulans': 0.06904921325744895,
#  'Periparus ater': 0.06904921325744895,
#  'Kryptopterus bicirrhis': 0.06904921325744895,
#  'Vespertilio sinensis': 0.06904921325744895,
#  'Cygnus columbianus': 0.06904921325744895,
#  'Arctocephalus australis': 0.06695681285570808,
#  'Alces alces': 0.0648644124539672,
#  'Phylloscopus proregulus': 0.0648644124539672,
#  'Corynorhinus rafinesquii': 0.0648644124539672,
#  'Python bivittatus': 0.0648644124539672,
#  'Prunella montanella': 0.06277201205222632,
#  'Microtus agrestis': 0.06277201205222632,
#  'Macaca arctoides': 0.06067961165048543,
#  'Felis domesticus': 0.05858721124874455,
#  'Rattus tanezumi': 0.05858721124874455,
#  'Pantholops hodgsonii': 0.05649481084700368,
#  'Miniopterus pusillus': 0.05649481084700368,
#  'Zoothera dauma': 0.05649481084700368,
#  'Turdus pallidus': 0.05649481084700368,
#  'Spheniscus demersus': 0.05649481084700368,
#  'Erinaceus europaeus': 0.054402410445262804,
#  'Emberiza chrysophrys': 0.054402410445262804,
#  'Turdus naumanni': 0.054402410445262804,
#  'Odocoileus virginianus': 0.052310010043521926,
#  'Phrynocephalus theobaldi': 0.052310010043521926,
#  'Acanthorhynchus tenuirostris': 0.052310010043521926,
#  'Suncus murinus': 0.052310010043521926,
#  'Gallus gallus domesticus': 0.052310010043521926,
#  'Eptesicus serotinus': 0.05021760964178105,
#  'Anas gracilis': 0.05021760964178105,
#  'Tursiops truncatus': 0.05021760964178105,
#  'Salmo salar': 0.05021760964178105,
#  'Cairina moschata': 0.05021760964178105,
#  'Phylloscopus schwarzi': 0.05021760964178105,
#  'Rattus rattus': 0.04812520924004017,
#  'Python regius': 0.04812520924004017}

# %%
df["prevalence"] = df["class"].apply(lambda x: metadata_unformatted[x])

# %%
len(metadata_formatted)
# Out:
# 143

# %%
len(metadata_unformatted)
# Out:
# 143

# %%
classes = list(metadata_unformatted.keys())
classes
# Out:
# ['Cyprinus carpio',
#  'Petroica australis',
#  'Felis catus',
#  'Gopherus morafkai',
#  'Peromyscus boylii',
#  'Marmota flaviventris',
#  'Bos taurus',
#  'Eptesicus fuscus',
#  'Macaca mulatta',
#  'Loxodonta africana',
#  'Mastomys natalensis',
#  'Gymnorhina tibicen',
#  'Eidolon helvum',
#  'Sparus aurata',
#  'Ailurus fulgens',
#  'Elephas maximus',
#  'Oryzomys sp.',
#  'Lates calcarifer',
#  'Bufo bufo',
#  'Crocodylus porosus',
#  'Hypsugo savii',
#  'Equus caballus',
#  'Dipodomys merriami',
#  'Rattus norvegicus',
#  'Crocodilurus amazonicus',
#  'Tarsiger cyanurus',
#  'Chelonia mydas',
#  'Mus musculus',
#  'Tursiops aduncus',
#  'Ovis aries',
#  'Tadarida brasiliensis',
#  'Rhinolophus ferrumequinum',
#  'Heloderma suspectum',
#  'Pteropus scapulatus',
#  'Anas superciliosa',
#  'Squalius cephalus',
#  'Oryctolagus cuniculus',
#  'Coendou prehensilis',
#  'Anas castanea',
#  'Grus japonensis',
#  'Amazona oratrix',
#  'Callorhinus ursinus',
#  'Phylloscopus inornatus',
#  'Macaca fuscata',
#  'Hoplobatrachus rugulosus',
#  'Phrynocephalus erythrurus',
#  'Miniopterus schreibersii',
#  'Peromyscus truei',
#  'Marmota marmota',
#  'Rhinella marina',
#  'Gorilla gorilla',
#  'Camelus dromedarius',
#  'Rhinolophus sinicus',
#  'Pygoscelis antarcticus',
#  'Equus asinus',
#  'Pygoscelis adeliae',
#  'Boa constrictor',
#  'Ailuropoda melanoleuca',
#  'Myotis ricketti',
#  'Rhinolophus affinis',
#  'Rousettus aegyptiacus',
#  'Leptonychotes weddellii',
#  'Ficedula parva',
#  'Macaca fascicularis',
#  'Myodes glareolus',
#  'Motacilla cinerea',
#  'Myotis daubentonii',
#  'Retropinna retropinna',
#  'Apodemus flavicollis',
#  'Acinonyx jubatus',
#  'Turdus hortulorum',
#  'Desmodus rotundus',
#  'Larvivora sibilans',
#  'Phoenicurus auroreus',
#  'Cecropis daurica',
#  'Phascolarctos cinereus',
#  'Aegithalos caudatus',
#  'Miniopterus magnater',
#  'Vulpes vulpes',
#  'Scotophilus kuhlii',
#  'Pan troglodytes',
#  'Anas platyrhynchos',
#  'Emberiza spodocephala',
#  'Ambystoma tigrinum',
#  'Phylloscopus fuscatus',
#  'Enhydra lutris',
#  'Rousettus leschenaultii',
#  'Grallina cyanoleuca',
#  'Cavia porcellus',
#  'Sarcophilus harrisii',
#  'Chenonetta jubata',
#  'Papio anubis',
#  'Pavo cristatus',
#  'Pteropus tonganus',
#  'Apodemus agrarius',
#  'Capra hircus',
#  'Dendrocopos leucotos',
#  'Pipistrellus pipistrellus',
#  'Lanius cristatus',
#  'Fringilla montifringilla',
#  'Anguilla australis',
#  'Meleagris gallopavo',
#  'Luscinia cyanura',
#  'Rhinolophus thomasi',
#  'Pteropus giganteus',
#  'Arctocephalus tropicalis',
#  'Mandrillus sphinx',
#  'Rattus exulans',
#  'Periparus ater',
#  'Kryptopterus bicirrhis',
#  'Vespertilio sinensis',
#  'Cygnus columbianus',
#  'Arctocephalus australis',
#  'Alces alces',
#  'Phylloscopus proregulus',
#  'Corynorhinus rafinesquii',
#  'Python bivittatus',
#  'Prunella montanella',
#  'Microtus agrestis',
#  'Macaca arctoides',
#  'Felis domesticus',
#  'Rattus tanezumi',
#  'Pantholops hodgsonii',
#  'Miniopterus pusillus',
#  'Zoothera dauma',
#  'Turdus pallidus',
#  'Spheniscus demersus',
#  'Erinaceus europaeus',
#  'Emberiza chrysophrys',
#  'Turdus naumanni',
#  'Odocoileus virginianus',
#  'Phrynocephalus theobaldi',
#  'Acanthorhynchus tenuirostris',
#  'Suncus murinus',
#  'Gallus gallus domesticus',
#  'Eptesicus serotinus',
#  'Anas gracilis',
#  'Tursiops truncatus',
#  'Salmo salar',
#  'Cairina moschata',
#  'Phylloscopus schwarzi',
#  'Rattus rattus',
#  'Python regius']

# %%
classes_order = {k:i for i, k in enumerate(classes)}
classes_order
# Out:
# {'Cyprinus carpio': 0,
#  'Petroica australis': 1,
#  'Felis catus': 2,
#  'Gopherus morafkai': 3,
#  'Peromyscus boylii': 4,
#  'Marmota flaviventris': 5,
#  'Bos taurus': 6,
#  'Eptesicus fuscus': 7,
#  'Macaca mulatta': 8,
#  'Loxodonta africana': 9,
#  'Mastomys natalensis': 10,
#  'Gymnorhina tibicen': 11,
#  'Eidolon helvum': 12,
#  'Sparus aurata': 13,
#  'Ailurus fulgens': 14,
#  'Elephas maximus': 15,
#  'Oryzomys sp.': 16,
#  'Lates calcarifer': 17,
#  'Bufo bufo': 18,
#  'Crocodylus porosus': 19,
#  'Hypsugo savii': 20,
#  'Equus caballus': 21,
#  'Dipodomys merriami': 22,
#  'Rattus norvegicus': 23,
#  'Crocodilurus amazonicus': 24,
#  'Tarsiger cyanurus': 25,
#  'Chelonia mydas': 26,
#  'Mus musculus': 27,
#  'Tursiops aduncus': 28,
#  'Ovis aries': 29,
#  'Tadarida brasiliensis': 30,
#  'Rhinolophus ferrumequinum': 31,
#  'Heloderma suspectum': 32,
#  'Pteropus scapulatus': 33,
#  'Anas superciliosa': 34,
#  'Squalius cephalus': 35,
#  'Oryctolagus cuniculus': 36,
#  'Coendou prehensilis': 37,
#  'Anas castanea': 38,
#  'Grus japonensis': 39,
#  'Amazona oratrix': 40,
#  'Callorhinus ursinus': 41,
#  'Phylloscopus inornatus': 42,
#  'Macaca fuscata': 43,
#  'Hoplobatrachus rugulosus': 44,
#  'Phrynocephalus erythrurus': 45,
#  'Miniopterus schreibersii': 46,
#  'Peromyscus truei': 47,
#  'Marmota marmota': 48,
#  'Rhinella marina': 49,
#  'Gorilla gorilla': 50,
#  'Camelus dromedarius': 51,
#  'Rhinolophus sinicus': 52,
#  'Pygoscelis antarcticus': 53,
#  'Equus asinus': 54,
#  'Pygoscelis adeliae': 55,
#  'Boa constrictor': 56,
#  'Ailuropoda melanoleuca': 57,
#  'Myotis ricketti': 58,
#  'Rhinolophus affinis': 59,
#  'Rousettus aegyptiacus': 60,
#  'Leptonychotes weddellii': 61,
#  'Ficedula parva': 62,
#  'Macaca fascicularis': 63,
#  'Myodes glareolus': 64,
#  'Motacilla cinerea': 65,
#  'Myotis daubentonii': 66,
#  'Retropinna retropinna': 67,
#  'Apodemus flavicollis': 68,
#  'Acinonyx jubatus': 69,
#  'Turdus hortulorum': 70,
#  'Desmodus rotundus': 71,
#  'Larvivora sibilans': 72,
#  'Phoenicurus auroreus': 73,
#  'Cecropis daurica': 74,
#  'Phascolarctos cinereus': 75,
#  'Aegithalos caudatus': 76,
#  'Miniopterus magnater': 77,
#  'Vulpes vulpes': 78,
#  'Scotophilus kuhlii': 79,
#  'Pan troglodytes': 80,
#  'Anas platyrhynchos': 81,
#  'Emberiza spodocephala': 82,
#  'Ambystoma tigrinum': 83,
#  'Phylloscopus fuscatus': 84,
#  'Enhydra lutris': 85,
#  'Rousettus leschenaultii': 86,
#  'Grallina cyanoleuca': 87,
#  'Cavia porcellus': 88,
#  'Sarcophilus harrisii': 89,
#  'Chenonetta jubata': 90,
#  'Papio anubis': 91,
#  'Pavo cristatus': 92,
#  'Pteropus tonganus': 93,
#  'Apodemus agrarius': 94,
#  'Capra hircus': 95,
#  'Dendrocopos leucotos': 96,
#  'Pipistrellus pipistrellus': 97,
#  'Lanius cristatus': 98,
#  'Fringilla montifringilla': 99,
#  'Anguilla australis': 100,
#  'Meleagris gallopavo': 101,
#  'Luscinia cyanura': 102,
#  'Rhinolophus thomasi': 103,
#  'Pteropus giganteus': 104,
#  'Arctocephalus tropicalis': 105,
#  'Mandrillus sphinx': 106,
#  'Rattus exulans': 107,
#  'Periparus ater': 108,
#  'Kryptopterus bicirrhis': 109,
#  'Vespertilio sinensis': 110,
#  'Cygnus columbianus': 111,
#  'Arctocephalus australis': 112,
#  'Alces alces': 113,
#  'Phylloscopus proregulus': 114,
#  'Corynorhinus rafinesquii': 115,
#  'Python bivittatus': 116,
#  'Prunella montanella': 117,
#  'Microtus agrestis': 118,
#  'Macaca arctoides': 119,
#  'Felis domesticus': 120,
#  'Rattus tanezumi': 121,
#  'Pantholops hodgsonii': 122,
#  'Miniopterus pusillus': 123,
#  'Zoothera dauma': 124,
#  'Turdus pallidus': 125,
#  'Spheniscus demersus': 126,
#  'Erinaceus europaeus': 127,
#  'Emberiza chrysophrys': 128,
#  'Turdus naumanni': 129,
#  'Odocoileus virginianus': 130,
#  'Phrynocephalus theobaldi': 131,
#  'Acanthorhynchus tenuirostris': 132,
#  'Suncus murinus': 133,
#  'Gallus gallus domesticus': 134,
#  'Eptesicus serotinus': 135,
#  'Anas gracilis': 136,
#  'Tursiops truncatus': 137,
#  'Salmo salar': 138,
#  'Cairina moschata': 139,
#  'Phylloscopus schwarzi': 140,
#  'Rattus rattus': 141,
#  'Python regius': 142}

# %%
len(classes)
# Out:
# 143

# %%
import math

def get_uniformly_divided_position_bins(positions, n_bins):
    bin_width = math.ceil(len(positions)/n_bins)
    bins = []
    start = 0
    for i in range(n_bins):
        end = start + bin_width
        bins.append(positions[start:end])
        start = end
        print(f"Bin length {i} = {len(bins[i])}")
    return bins

# %%
# plt.rcParams['xtick.labelsize'] = 15
# plt.rcParams['ytick.labelsize'] = 15

plt.rcParams['figure.autolayout'] = True
plt.clf()
fig, axs = plt.subplots(1, 3, figsize=(36, 28), sharex=True)
plt.rcParams['xtick.labelsize'] = 28
plt.rcParams['ytick.labelsize'] = 28
#plt.rcParams.update({'font.size': 30})

df.sort_values(by=["class"], key=lambda x: x.map(classes_order), inplace=True)
formatted_df = df.replace({"class": metadata_formatted})
classes = list(formatted_df["class"].unique())
print(f"Number of unique classes = {len(classes)}")
bins = get_uniformly_divided_position_bins(list(classes), 3)
for i in range(3):
    #sns.violinplot(data=df[df["class"].isin(bins[i])],  x="auprc", y="class", hue="model", ax=axs[i], split=True, orient="h", linewidth=2.5, fill=False,  order=bins[i])
    sns.boxplot(data=formatted_df[formatted_df["class"].isin(bins[i])],  x="auprc", y="class", ax=axs[i], orient="h", linewidth=5, fill=False, fliersize=12, order=bins[i])
    
    #sns.stripplot(data=formatted_df[formatted_df["class"].isin(bins[i])], x="auprc", y="class", ax=axs[i], orient="h", color="black", order=bins[i])
    #plt.draw()

    axs[i].set_ylabel("")
    axs[i].set_xlabel("AUPRC", fontsize="30")

plt.tight_layout()
plt.savefig(os.path.join(os.getcwd(), "..","..", "..", "output/visualization/haven/host_multi_fsl_non_idv_lt1_gte0.05_prcnt_classwise_boxplot.pdf"), dpi=1024, bbox_inches="tight")
plt.show()
# Out:
# Number of unique classes = 99
# Bin length 0 = 33
# Bin length 1 = 33
# Bin length 2 = 33

# %%
min_prevalence = df["prevalence"].min()
print(f"min prevalence = {min_prevalence}")
min_prevalence_df = df[df["prevalence"] == min_prevalence]
min_prevalence_df[["class", "auprc"]].groupby("class").agg(["min", "max", "mean", "median"])
# Out:
# min prevalence = 0.05021760964178105
#                         auprc
#                           min       max      mean    median
# class
# Anas gracilis        0.152485  0.523023  0.256761  0.235075
# Eptesicus serotinus  0.081264  0.867060  0.423594  0.438817
# Salmo salar          0.188875  0.932663  0.552773  0.511312
# Tursiops truncatus   0.123463  0.747728  0.411991  0.465829

# %%
dataset_df["virus_host_name"].value_counts()["Salmo salar"]
# Out:
# 24

# %%
max_prevalence = df["prevalence"].max()
print(f"max prevalence = {max_prevalence}")
max_prevalence_df = df[df["prevalence"] == max_prevalence]
max_prevalence_df[["class", "auprc"]].groupby("class").agg(["min", "max", "mean", "median"])
# Out:
# max prevalence = 0.8536993639102779
#                        auprc
#                          min       max      mean    median
# class
# Petroica australis  0.902619  0.985065  0.952442  0.953495

# %%
dataset_df["virus_host_name"].value_counts()["Petroica australis"]
# Out:
# 408

# %%
mean_auprc_df = df[["model", "class", "auprc"]].groupby(["model", "class"]).agg("mean").reset_index()
mean_auprc_df["prevalence"] = mean_auprc_df["class"].apply(lambda x: metadata_unformatted[x])
mean_auprc_df
# Out:
#              model                   class     auprc  prevalence
# 0   sl256st64_w3s5        Acinonyx jubatus  0.687577    0.096250
# 1   sl256st64_w3s5  Ailuropoda melanoleuca  0.744852    0.104620
# 2   sl256st64_w3s5         Ailurus fulgens  0.877106    0.364078
# 3   sl256st64_w3s5         Amazona oratrix  0.625156    0.163207
# 4   sl256st64_w3s5           Anas castanea  0.736546    0.190408
# ..             ...                     ...       ...         ...
# 94  sl256st64_w3s5         Turdus naumanni  0.383094    0.054402
# 95  sl256st64_w3s5        Tursiops aduncus  0.873234    0.240626
# 96  sl256st64_w3s5      Tursiops truncatus  0.411991    0.050218
# 97  sl256st64_w3s5           Vulpes vulpes  0.515944    0.087881
# 98  sl256st64_w3s5          Zoothera dauma  0.295616    0.056495
#
# [99 rows x 4 columns]

# %%
print(f"Lowest mean AUPRC = {mean_auprc_df['auprc'].min()}")
print(f"Maximum mean AUPRC = {mean_auprc_df['auprc'].max()}")
# Out:
# Lowest mean AUPRC = 0.2567609650068991
# Maximum mean AUPRC = 0.9636952648377559

# %%
median_auprc_df = df[["model", "class", "auprc"]].groupby(["model", "class"]).agg("median").reset_index()
median_auprc_df["prevalence"] = median_auprc_df["class"].apply(lambda x: metadata_unformatted[x])
median_auprc_df
# Out:
#              model                   class     auprc  prevalence
# 0   sl256st64_w3s5        Acinonyx jubatus  0.797278    0.096250
# 1   sl256st64_w3s5  Ailuropoda melanoleuca  0.714786    0.104620
# 2   sl256st64_w3s5         Ailurus fulgens  0.899991    0.364078
# 3   sl256st64_w3s5         Amazona oratrix  0.622922    0.163207
# 4   sl256st64_w3s5           Anas castanea  0.788884    0.190408
# ..             ...                     ...       ...         ...
# 94  sl256st64_w3s5         Turdus naumanni  0.354023    0.054402
# 95  sl256st64_w3s5        Tursiops aduncus  0.949661    0.240626
# 96  sl256st64_w3s5      Tursiops truncatus  0.465829    0.050218
# 97  sl256st64_w3s5           Vulpes vulpes  0.500855    0.087881
# 98  sl256st64_w3s5          Zoothera dauma  0.225225    0.056495
#
# [99 rows x 4 columns]

# %%
print(f"Lowest median AUPRC = {median_auprc_df['auprc'].min()}")
print(f"Maximum median AUPRC = {median_auprc_df['auprc'].max()}")
# Out:
# Lowest median AUPRC = 0.2252251817262319
# Maximum median AUPRC = 0.9866364723970629

# %%
median_prevalence = np.median(np.array(list(metadata_unformatted.values())))
print(f"Median class prevalence = {median_prevalence}")
print(f"Median number of samples = {median_prevalence * 47792/100}")

mean_prevalence = np.mean(np.array(list(metadata_unformatted.values())))
print(f"Mean class prevalence = {mean_prevalence}")
print(f"Mean number of samples = {mean_prevalence * 47792/100}")
# Out:
# Median class prevalence = 0.09415801807833947
# Median number of samples = 45.0
# Mean class prevalence = 0.16265120885140974
# Mean number of samples = 77.73426573426575

# %%
print(f"Median auprc = {df['auprc'].median()}")
print(f"Mean auprc = {df['auprc'].mean()}")
# Out:
# Median auprc = 0.6779599337916302
# Mean auprc = 0.6504887798769238

# %%
plt.clf()
plt.figure(figsize=(8,8))
#plt.rcParams["figure.autolayout"] = True
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams.update({'font.size': 18})


ax = sns.jointplot(data=df, x="prevalence", y="auprc",
                   height=8, ylim=(0, 1),  xlim=(0, 1),
                   ratio=2, marginal_ticks=True, legend=True)
ax.plot_joint(sns.scatterplot, alpha=1, s=50, edgecolor=".2", linewidth=.5)
ax.plot_marginals(sns.histplot, kde=False, fill=False, color="0.2", line_kws={"color": "black", "lw": 3, "ls": "-"})
#ax = sns.scatterplot(mean_auprc_df, x="prevalance", y="auprc", hue="model", alpha=1)

# ax = sns.JointGrid()
# x, y = penguins["bill_length_mm"], penguins["bill_depth_mm"]
# sns.scatterplot(data=df, x="prevalence", y="auprc", ec="b", fc="none", s=100, linewidth=1.5, ax=g.ax_joint)
# sns.histplot(x=x, fill=False, linewidth=2, ax=g.ax_marg_x)
# sns.kdeplot(y=y, linewidth=2, ax=g.ax_marg_y)


ax.ax_joint.set_xlabel("Class Prevalence (%)", fontsize=18)
ax.ax_joint.set_ylabel("AUPRC", fontsize=18)
ax.ax_joint.xaxis.set_major_locator(ticker.MultipleLocator(.1))
ax.ax_joint.xaxis.set_major_formatter(ticker.ScalarFormatter())
ax.ax_joint.yaxis.set_major_locator(ticker.MultipleLocator(.1))
ax.ax_joint.yaxis.set_major_formatter(ticker.ScalarFormatter())

ax.ax_marg_x.set_ylabel("Class Prevalence (%)")
ax.ax_marg_y.set_ylabel("ABCD")


ax.ax_marg_x.axvline(df["prevalence"].median(), color='r', ls='--', lw=3)
ax.ax_marg_y.axhline(df["auprc"].median(), color='r', ls='--', lw=3)

ax.ax_marg_x.annotate(f"median class prevalence={'{0:.2f}%'.format(df['prevalence'].median())}", xy=(df["prevalence"].median(), 450), xycoords="data",
            xytext=(df["prevalence"].median() + .04, 450), textcoords='data',
            va='top', ha='left')

ax.ax_marg_y.annotate(f"median AUPRC={'{0:.2f}'.format(df['auprc'].median())}", xy=(102, df["auprc"].median()), xycoords="data",
            xytext=(150, df["prevalence"].median()+.55), textcoords='data',
            va='top', ha='left', rotation=-90)

ax = plt.gca()
ax.figure.tight_layout()
plt.savefig(os.path.join(os.getcwd(), "..","..", "..", "output/visualization/haven/host_multi_fsl_non_idv_lt1_gte0.05_prcnt_auprc_scatterplot_w_hist.pdf"), dpi=1024, bbox_inches="tight")
plt.show()
