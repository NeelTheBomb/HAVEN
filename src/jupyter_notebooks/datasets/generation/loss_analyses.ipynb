# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# # Analyzing the probabilities after fine tuning
#
# <b> We had different tests for the fine tuning outputs: </b>
#
# - using different div factor (25), final div factor (20000) and max_lr of 1e-5 instead of 3e-4
# - using original div factors (50), final div factor (10000) and max lr of 1e-5
# - using the original div factors and max lr of 1e-5 but changing epoch values to n_epochs_freeze: 40 and n_epochs_unfreeze: 60

# %% [markdown]
# <b> First Scenario </b>
#
# - add pretty high peaks and a validation loss that went in a concave down shape and went slightly above 2.5
# - training loss had several peaks, the highest ones stayed at 3. downward trend
#
# file name: mlm_tfenc_l6_h8_lr1e-5_uniref50viridae_vs30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr1e-5_changeddivs_output.csv

# %%
file_path = os.path.join(os.getcwd(), "..", "..", "..","..", "/home/sanjanag05/HAVEN/output/raw/uniref50_coronaviridae/uniref50_corona_top_hosts/mlm_tfenc_l6_h8_lr1e-5_uniref50viridae_vs30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr1e-5_changeddivs_output.csv")
df1 = pd.read_csv(file_path)
df1
# Out:
#     Unnamed: 0       Cat   Chicken  European rabbit  Gray wolf     Human  \
# 0            0  0.488431  0.119620         0.107170   0.164037  0.042756
# 1            1  0.006096  0.005043         0.057526   0.035703  0.736756
# 2            2  0.457689  0.114514         0.119851   0.176393  0.043528
# 3            3  0.155254  0.037704         0.031280   0.165881  0.434863
# 4            4  0.367276  0.214597         0.094599   0.152804  0.044583
# 5            5  0.476737  0.118777         0.118038   0.154226  0.041961
# 6            6  0.139878  0.197709         0.201787   0.096321  0.203780
# 7            7  0.275725  0.083988         0.255378   0.173927  0.102848
# 8            8  0.471984  0.107320         0.112929   0.169816  0.039518
# 9            9  0.556103  0.110186         0.087611   0.140735  0.039593
# 10          10  0.404554  0.164155         0.105341   0.165859  0.068792
# 11          11  0.327615  0.203185         0.173764   0.090086  0.090168
# 12          12  0.147179  0.278118         0.088741   0.086756  0.073171
# 13          13  0.195020  0.356672         0.119770   0.099136  0.054285
# 14          14  0.476118  0.133824         0.090526   0.173359  0.042631
# 15          15  0.536084  0.125617         0.083805   0.131748  0.047139
# 16          16  0.314548  0.089787         0.128452   0.180247  0.185907
# 17          17  0.372370  0.143882         0.142604   0.194712  0.048367
# 18          18  0.059199  0.234979         0.092476   0.130291  0.149585
# 19          19  0.489304  0.186818         0.090885   0.103982  0.045858
# 20          20  0.271921  0.109856         0.191283   0.270542  0.046248
# 21          21  0.347015  0.114143         0.149449   0.173433  0.123336
# 22          22  0.249669  0.290209         0.151817   0.162383  0.043126
# 23          23  0.382880  0.086298         0.176010   0.172820  0.081438
# 24          24  0.110747  0.232590         0.151347   0.111956  0.220590
# 25          25  0.433733  0.145535         0.126945   0.162038  0.060179
# 26          26  0.077772  0.052593         0.039588   0.148231  0.626105
#
#          Pig           y_true  itr
# 0   0.077985            Human    0
# 1   0.158875            Human    0
# 2   0.088025  European rabbit    0
# 3   0.175017            Human    0
# 4   0.126141              Pig    0
# 5   0.090261          Chicken    0
# 6   0.160525            Human    0
# 7   0.108135          Chicken    0
# 8   0.098433              Cat    0
# 9   0.065772        Gray wolf    0
# 10  0.091298          Chicken    0
# 11  0.115183            Human    0
# 12  0.326035            Human    0
# 13  0.175116          Chicken    0
# 14  0.083542              Cat    0
# 15  0.075607            Human    0
# 16  0.101059            Human    0
# 17  0.098065          Chicken    0
# 18  0.333471            Human    0
# 19  0.083152              Cat    0
# 20  0.110150              Pig    0
# 21  0.092624            Human    0
# 22  0.102795          Chicken    0
# 23  0.100554            Human    0
# 24  0.172771            Human    0
# 25  0.071571              Cat    0
# 26  0.055711            Human    0

# %% [markdown]
# <b> Second Scenario </b>
#
# - validation loss peak did not go as high as first scenario, went slightly above 2
# - training loss had similar peaks to the first one, but the highest peak went up to 5
#   more downward trends for this scenario
# - changes were not too significant, but noticeable, slightly better.
# - This is why we kept the og div factors for new third scenario
#
# file name: mlm_tfenc_l6_h8_lr1e-5pt2_uniref50viridae_vs30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr1e-5_ogdiv_output.csv

# %%
file_path = os.path.join(os.getcwd(), "..", "..", "..","..", "/home/sanjanag05/HAVEN/output/raw/uniref50_coronaviridae/uniref50_corona_top_hosts/mlm_tfenc_l6_h8_lr1e-5pt2_uniref50viridae_vs30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr1e-5_ogdiv_output.csv")
df2 = pd.read_csv(file_path)
df2
# Out:
#     Unnamed: 0       Cat   Chicken  European rabbit  Gray wolf     Human  \
# 0            0  0.088187  0.271152         0.102075   0.071075  0.401196
# 1            1  0.066186  0.290296         0.121944   0.096449  0.229588
# 2            2  0.336019  0.159752         0.182982   0.129978  0.098078
# 3            3  0.387805  0.171284         0.175168   0.117887  0.085982
# 4            4  0.327489  0.300782         0.092682   0.075828  0.127570
# 5            5  0.015618  0.004327         0.101559   0.029578  0.472946
# 6            6  0.135524  0.524873         0.077390   0.060578  0.106022
# 7            7  0.282553  0.214373         0.198927   0.138442  0.070731
# 8            8  0.364214  0.176297         0.179731   0.102045  0.095680
# 9            9  0.116961  0.249136         0.178364   0.081980  0.178546
# 10          10  0.117641  0.103288         0.080680   0.175480  0.408922
# 11          11  0.356995  0.154931         0.178183   0.152312  0.065946
# 12          12  0.330487  0.160427         0.228082   0.120131  0.077259
# 13          13  0.339405  0.193750         0.179143   0.129699  0.078401
# 14          14  0.110929  0.352511         0.116778   0.062832  0.288016
# 15          15  0.079860  0.250052         0.097221   0.125538  0.277936
# 16          16  0.504425  0.112139         0.030971   0.095326  0.137636
# 17          17  0.301571  0.237812         0.096941   0.085186  0.210257
# 18          18  0.094358  0.398756         0.048282   0.029302  0.111338
# 19          19  0.274568  0.268611         0.168715   0.087415  0.099302
# 20          20  0.046245  0.141501         0.056757   0.104153  0.599276
# 21          21  0.113990  0.070861         0.106290   0.046052  0.604025
# 22          22  0.312095  0.272253         0.047525   0.102406  0.106289
# 23          23  0.139877  0.105691         0.347452   0.087182  0.058992
# 24          24  0.025933  0.155666         0.049917   0.050123  0.489980
# 25          25  0.141385  0.118544         0.179543   0.061625  0.430321
# 26          26  0.068968  0.560277         0.125147   0.090411  0.072432
#
#          Pig           y_true  itr
# 0   0.066314            Human    0
# 1   0.195537            Human    0
# 2   0.093191            Human    0
# 3   0.061873              Cat    0
# 4   0.075649          Chicken    0
# 5   0.375973            Human    0
# 6   0.095614          Chicken    0
# 7   0.094974            Human    0
# 8   0.082032          Chicken    0
# 9   0.195012          Chicken    0
# 10  0.113989            Human    0
# 11  0.091632              Pig    0
# 12  0.083614  European rabbit    0
# 13  0.079601          Chicken    0
# 14  0.068934            Human    0
# 15  0.169393            Human    0
# 16  0.119502              Cat    0
# 17  0.068234            Human    0
# 18  0.317964              Pig    0
# 19  0.101389        Gray wolf    0
# 20  0.052069            Human    0
# 21  0.058782            Human    0
# 22  0.159431              Cat    0
# 23  0.260806              Cat    0
# 24  0.228381            Human    0
# 25  0.068582            Human    0
# 26  0.082765          Chicken    0

# %% [markdown]
# <b> Third Scenario </b>
#
# - validation loss seemed worse here, has a slight upwards trend and peaks go up to 3
# - this scenario has the best training loss. it peaks up to 5, but there is only one significant peak
# - everything else about training loss is a nice downwards trend
#
# file name: mlm_tfenc_l6_h8_lr1e-6_uniref50viridae_vs30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr1e-5_changed_epochs_output.csv
#
#
# <b> This scenario is a good example of overfitting. While the training loss looked the best here, the validation loss increased. This means overfitting. Maybe because there were more epochs so the model learned all of the data's flaws as well, learned it too well, so it could not predict the validation loss correctly </b>

# %%
file_path = os.path.join(os.getcwd(), "..", "..", "..","..", "/home/sanjanag05/HAVEN/output/raw/uniref50_coronaviridae/uniref50_corona_top_hosts/mlm_tfenc_l6_h8_lr1e-6_uniref50viridae_vs30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr1e-5_changed_epochs_output.csv")
df3 = pd.read_csv(file_path)
df3
# Out:
#     Unnamed: 0       Cat   Chicken  European rabbit  Gray wolf     Human  \
# 0            0  0.412720  0.011013         0.031275   0.002056  0.389612
# 1            1  0.362624  0.183165         0.174434   0.231751  0.037420
# 2            2  0.477939  0.070878         0.186468   0.210256  0.045987
# 3            3  0.494084  0.086449         0.152638   0.218776  0.040195
# 4            4  0.390423  0.260975         0.121642   0.149621  0.054064
# 5            5  0.122762  0.389585         0.161531   0.127942  0.123373
# 6            6  0.633689  0.073781         0.097191   0.139924  0.047431
# 7            7  0.497602  0.076236         0.216027   0.142417  0.058193
# 8            8  0.077400  0.387162         0.265660   0.051248  0.160151
# 9            9  0.107136  0.247174         0.501241   0.043798  0.074604
# 10          10  0.569972  0.135673         0.126780   0.098746  0.056931
# 11          11  0.453713  0.088609         0.211752   0.193066  0.040030
# 12          12  0.551250  0.089369         0.136971   0.172549  0.042231
# 13          13  0.543136  0.071627         0.127033   0.148501  0.097935
# 14          14  0.057650  0.054545         0.066660   0.075342  0.729522
# 15          15  0.570221  0.062324         0.127311   0.160536  0.070423
# 16          16  0.036784  0.383956         0.168892   0.193021  0.111269
# 17          17  0.186390  0.304027         0.236788   0.215718  0.044009
# 18          18  0.055063  0.139927         0.177518   0.032403  0.578135
# 19          19  0.023401  0.293963         0.337938   0.047811  0.201549
# 20          20  0.256319  0.199242         0.344207   0.117376  0.069595
# 21          21  0.232401  0.183953         0.325904   0.198550  0.048613
# 22          22  0.188003  0.306114         0.266339   0.087279  0.135335
# 23          23  0.019807  0.077998         0.067455   0.042565  0.541229
# 24          24  0.416292  0.149132         0.233533   0.141273  0.049145
# 25          25  0.148890  0.091251         0.408061   0.051590  0.293473
# 26          26  0.497602  0.100460         0.112187   0.178301  0.098910
#
#          Pig           y_true  itr
# 0   0.153323            Human    0
# 1   0.010607          Chicken    0
# 2   0.008472  European rabbit    0
# 3   0.007859          Chicken    0
# 4   0.023276              Pig    0
# 5   0.074807            Human    0
# 6   0.007984            Human    0
# 7   0.009523          Chicken    0
# 8   0.058378            Human    0
# 9   0.026046          Chicken    0
# 10  0.011898              Cat    0
# 11  0.012830              Cat    0
# 12  0.007630              Cat    0
# 13  0.011769            Human    0
# 14  0.016281            Human    0
# 15  0.009186            Human    0
# 16  0.106079          Chicken    0
# 17  0.013068            Human    0
# 18  0.016954            Human    0
# 19  0.095338            Human    0
# 20  0.013261            Human    0
# 21  0.010580              Pig    0
# 22  0.016930          Chicken    0
# 23  0.250946            Human    0
# 24  0.010625        Gray wolf    0
# 25  0.006735            Human    0
# 26  0.012540              Cat    0

# %%
human = df[df["y_true"] == "Human"]
human
#when it predicts human
#rows 14 (0.729), 18(0.578), 23(0.541)
#otherwise, it seems to commonly predict cat, rows 0, 6, 13, 15

cat = df[df["y_true"] == "Cat"]
cat
#Always accurately predicts cat!. but it is not completely sure

chicken = df[df["y_true"] == "Chicken"]
chicken
#Margin is pretty small, but seems to predict cat more than chicken: rows 1,3,7
#row 9 predicts wolf rabbit
#rows 16 & 22 predicts chicken correctly!
#2/6 times it predicts correctly

pig = df[df["y_true"] == "Pig"]
pig

wolf = df[df["y_true"] == "Gray wolf"]
wolf

rabbit = df[df["y_true"] == "European rabbit"]
rabbit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 human = df[df["y_true"] == "Human"]
#       2 human
#       3 #when it predicts human
#       4 #rows 14 (0.729), 18(0.578), 23(0.541)
#       5 #otherwise, it seems to commonly predict cat, rows 0, 6, 13, 15
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Most recent

# %%
file_path = os.path.join(os.getcwd(), "..", "..", "..","..", "/home/sanjanag05/HAVEN/output/raw/uniref50_coronaviridae/uniref50_corona_top_hosts/mlm_1e-5_final.csv")
df_final = pd.read_csv(file_path)
df_final
# Out:
#      Unnamed: 0       Cat   Chicken  European rabbit  Gray wolf     Human  \
# 0             0  0.092565  0.154685         0.072600   0.173884  0.322611
# 1             1  0.413319  0.112904         0.113968   0.188249  0.064998
# 2             2  0.492880  0.106734         0.093377   0.136344  0.080404
# 3             3  0.038249  0.136735         0.158560   0.180364  0.444808
# 4             4  0.099614  0.220222         0.065730   0.196319  0.233449
# ..          ...       ...       ...              ...        ...       ...
# 130          22  0.103008  0.164551         0.247137   0.027413  0.070135
# 131          23  0.015092  0.081642         0.101963   0.016482  0.541764
# 132          24  0.076392  0.624302         0.076234   0.035920  0.133933
# 133          25  0.025209  0.142712         0.335596   0.042261  0.386422
# 134          26  0.031685  0.091008         0.489893   0.096894  0.253222
#
#           Pig   y_true  itr
# 0    0.183655    Human    0
# 1    0.106563      Pig    0
# 2    0.090262    Human    0
# 3    0.041285    Human    0
# 4    0.184666    Human    0
# ..        ...      ...  ...
# 130  0.387756  Chicken    4
# 131  0.243057  Chicken    4
# 132  0.053219    Human    4
# 133  0.067800    Human    4
# 134  0.037297    Human    4
#
# [135 rows x 9 columns]

# %% [markdown]
# # Confusion Matrix

# %%
host_col = ['Cat', 'Chicken', 'European rabbit', 'Gray wolf', 'Human', 'Pig']
df_final['y_pred'] = df_final[host_col].idxmax(axis=1)

cm = confusion_matrix(df_final['y_true'], df_final['y_pred'], labels=host_col)
scale = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
disp = ConfusionMatrixDisplay(confusion_matrix=scale, display_labels=host_col)
disp.plot(xticks_rotation=45, cmap='Blues', values_format = ".2f")
disp.im_.set_clim(0.0, 1.0)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Analysis
#
# - cat, chicken, and human are predicted pretty well. Although, the model often mixes up almost everything for cat.
# - For pig, it was not predicted correct even once.
# - Wolf was correct on two occurrences, but cat was also predicted for wolf twice.
# - Human was misclassified as Cat 15 times, which is a lot.
# - The model seems to be weak, and this can be seen in the validation loss graph.

# %%
file_path = os.path.join(os.getcwd(), "..", "..", "..","..", "/home/sanjanag05/HAVEN/output/raw/uniref50_coronaviridae/uniref50_corona_top_hosts/epoch2030_patience30_hybrid_attention_msl256s64ae_bn_cls_fnn_2l_d1024_lr3e-4_output.csv")
epoch50 = pd.read_csv(file_path)
epoch50
# Out:
#      Unnamed: 0       Cat   Chicken  European rabbit  Gray wolf     Human  \
# 0             0  0.398872  0.152777         0.091422   0.181038  0.056441
# 1             1  0.393981  0.115103         0.128366   0.180697  0.075718
# 2             2  0.120574  0.266738         0.110267   0.130844  0.254304
# 3             3  0.047741  0.020349         0.095062   0.045194  0.672489
# 4             4  0.335386  0.114368         0.112574   0.201955  0.112008
# ..          ...       ...       ...              ...        ...       ...
# 130          22  0.200702  0.094268         0.241082   0.221459  0.033929
# 131          23  0.319758  0.001276         0.086165   0.001743  0.180509
# 132          24  0.271091  0.030508         0.538765   0.084375  0.046733
# 133          25  0.097827  0.473063         0.074731   0.105753  0.152394
# 134          26  0.071900  0.113724         0.294093   0.065527  0.430491
#
#           Pig   y_true  itr
# 0    0.119450      Cat    0
# 1    0.106135    Human    0
# 2    0.117274    Human    0
# 3    0.119165    Human    0
# 4    0.123709    Human    0
# ..        ...      ...  ...
# 130  0.208560      Pig    4
# 131  0.410549    Human    4
# 132  0.028528    Human    4
# 133  0.096231  Chicken    4
# 134  0.024265    Human    4
#
# [135 rows x 9 columns]

# %%
host_col = ['Cat', 'Chicken', 'European rabbit', 'Gray wolf', 'Human', 'Pig']
epoch50['y_pred'] = epoch50[host_col].idxmax(axis=1)

cm = confusion_matrix(epoch50['y_true'], epoch50['y_pred'], labels=host_col)
scale = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
disp = ConfusionMatrixDisplay(confusion_matrix=scale, display_labels=host_col)
disp.plot(xticks_rotation=45, cmap='Blues', values_format=".2f")
disp.im_.set_clim(0.0, 1.0)
plt.title("Confusion Matrix")
plt.show()
    


# # Normalize the confusion matrix by row (true label)
# cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# # Plot
# disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=host_col)
# disp.plot(xticks_rotation=45, cmap='Blues', values_format=".2f")  # shows values as decimals
# plt.title("Normalized Confusion Matrix (Per Class)")
# plt.show()

# %%
file_path = os.path.join(os.getcwd(), "..", "..", "..","..", "/home/sanjanag05/HAVEN/output/raw/uniref50_coronaviridae/uniref50_corona_top_hosts/epochs40_60_patience_30.csv")
epoch100 = pd.read_csv(file_path)
epoch100
# Out:
#      Unnamed: 0       Cat   Chicken  European rabbit  Gray wolf     Human  \
# 0             0  0.569137  0.092541         0.101969   0.135346  0.036523
# 1             1  0.630755  0.121122         0.088202   0.098533  0.018917
# 2             2  0.112685  0.008332         0.198174   0.108836  0.302285
# 3             3  0.482172  0.231771         0.078845   0.085245  0.061163
# 4             4  0.026982  0.020275         0.054023   0.053659  0.770988
# ..          ...       ...       ...              ...        ...       ...
# 130          22  0.156593  0.038792         0.172112   0.286937  0.283893
# 131          23  0.081046  0.001294         0.133650   0.040270  0.671416
# 132          24  0.036666  0.254386         0.096855   0.272912  0.115845
# 133          25  0.139783  0.208992         0.094913   0.157980  0.328311
# 134          26  0.196374  0.113420         0.168390   0.101373  0.082141
#
#           Pig   y_true  itr
# 0    0.064485    Human    0
# 1    0.042471      Cat    0
# 2    0.269689    Human    0
# 3    0.060804  Chicken    0
# 4    0.074073    Human    0
# ..        ...      ...  ...
# 130  0.061673    Human    4
# 131  0.072325    Human    4
# 132  0.223336  Chicken    4
# 133  0.070021    Human    4
# 134  0.338302      Cat    4
#
# [135 rows x 9 columns]

# %%
host_col = ['Cat', 'Chicken', 'European rabbit', 'Gray wolf', 'Human', 'Pig']
epoch100['y_pred'] = epoch100[host_col].idxmax(axis=1)

cm = confusion_matrix(epoch100['y_true'], epoch100['y_pred'], labels=host_col)
scale = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
disp = ConfusionMatrixDisplay(confusion_matrix=scale, display_labels=host_col)
disp.plot(xticks_rotation=45, cmap='Blues', values_format=".2f")
disp.im_.set_clim(0.0, 1.0)
plt.title("Confusion Matrix")
plt.show()
